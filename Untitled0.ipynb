# %% [markdown]
# <a href="https://colab.research.google.com/github/Kunj125/time-complexity/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# x_random = np.array([5, 10,20,30,50,80,100,150,200,500])
# y_random = np.array([0.235, 0.235, 0.266, 0.298, 0.374, 0.455, 0.503, 0.601, 0.780, 1.735])

# x_sort = np.array([5, 10,20,30,50,80,100,150,200,500])
# y_sort = np.array([0.217, 0.249, 0.268, 0.315, 0.358, 0.443, 0.487, 0.619, 0.798, 1.814])

# x_reverse = np.array([5, 10,20,30,50,80,100,150,200,500])
# y_reverse = np.array([0.460, 1.110, 3.779, 8.309, 22.426, 43.349, 124.842, 329.0465, 727.568, 5456.76])

# without 500
x_random = np.array([5, 10,20,30,50,80,100,150,200])
y_random = np.array([0.235, 0.235, 0.266, 0.298, 0.374, 0.455, 0.503, 0.601, 0.780])

x_sort = np.array([5, 10,20,30,50,80,100,150,200])
y_sort = np.array([0.217, 0.249, 0.268, 0.315, 0.358, 0.443, 0.487, 0.619, 0.798])

x_reverse = np.array([5, 10,20,30,50,80,100,150,200])
y_reverse = np.array([0.460, 1.110, 3.779, 8.309, 22.426, 43.349, 124.842, 329.0465, 727.568])

plt.plot(x_random, y_random, label= "random")
plt.plot(x_sort, y_sort, label= "sorted" )
plt.plot(x_reverse, y_reverse, label= "reverse sorted" )


plt.scatter(x_random, y_random)
plt.scatter(x_sort, y_sort)
plt.scatter(x_reverse, y_reverse)


plt.xlabel("Size of Dictionary (in thousands)")
plt.ylabel("Time (in seconds)")
plt.legend()

plt.show()

# %%
plt.plot(x_random, y_random, label= "random" )
plt.scatter(x_random, y_random)

plt.xlabel("Size of Dictionary (in thousands)")
plt.ylabel("Time (in seconds)")
plt.legend()

# %%
plt.plot(x_sort, y_sort, label= "sorted" )
plt.scatter(x_sort, y_sort)

plt.xlabel("Size of Dictionary (in thousands)")
plt.ylabel("Time (in seconds)")
plt.legend()

# %%
plt.plot(x_reverse, y_reverse, label= "reverse sorted" )
plt.scatter(x_reverse, y_reverse)

plt.xlabel("Size of Dictionary (in thousands)")
plt.ylabel("Time (in seconds)")
plt.legend()
